# %% [markdown]
# # Hello Word

# %% [markdown]
# $f(n)=\frac{x+1}{x+2}$
# ## subtitle

# %%
import matplotlib.pyplot as plt
from pylab import *
x = linspace(0,5,10)
y = x**2
figure()
plot(x,y,"r")
xlabel("x")
ylabel("y")
title("title")
show()
